# %% [markdown]
# ## __Why we need Seperate Chaining?__
#
# A hash table, a data structure that maps keys to values, has two parts, the actual table where the data is stored, and the hash function used to map the index keys to values. In normal operations, the hash table evaluates input data and then assigns an index key (table location) to that value. Now, when two different keys hash to the same index in a hash table a collision is said to have occurred. Memory is limited, and systems would need an incredible amount of memory for collisions not to occur. Collisions are generally evenly distributed around the hash table. This means that no single position on the hash table will be unduly overwhelmed with a long list of collisions compared to other locations within the table.

# %%
import random
from functools import reduce

# %%
#sp = [[]] * 256 #Any appending will add things to all indexes so not that useful in this case
sp = [[] for _ in range(256)]
hash_table = [0] * 256
phone_numbers = "1234567890"
phone = []

# %%
def phone_number_creator():
    global phone_numbers
    num = [random.choice(phone_numbers) for i in range(10)] 
    return "".join(num)

# %%
for i in range(100):
    phone.append(phone_number_creator())

# %%
for p in phone:
    key = reduce(lambda x,y:int(x)+int(y),p)
    if hash_table[key] == 0:
        hash_table[key] = p
    else:
        sp[key].append(p)

# %%
for i in range(256):
    print("hash_Index : {} : value {} : Seprate Chain : {}".format(i,hash_table[i],sp[i]))
# Out:
# hash_Index : 0 : value 0 : Seprate Chain : []
# hash_Index : 1 : value 0 : Seprate Chain : []
# hash_Index : 2 : value 0 : Seprate Chain : []
# hash_Index : 3 : value 0 : Seprate Chain : []
# hash_Index : 4 : value 0 : Seprate Chain : []
# hash_Index : 5 : value 0 : Seprate Chain : []
# hash_Index : 6 : value 0 : Seprate Chain : []
# hash_Index : 7 : value 0 : Seprate Chain : []
# hash_Index : 8 : value 0 : Seprate Chain : []
# hash_Index : 9 : value 0 : Seprate Chain : []
# hash_Index : 10 : value 0 : Seprate Chain : []
# hash_Index : 11 : value 0 : Seprate Chain : []
# hash_Index : 12 : value 0 : Seprate Chain : []
# hash_Index : 13 : value 0 : Seprate Chain : []
# hash_Index : 14 : value 0 : Seprate Chain : []
# hash_Index : 15 : value 0 : Seprate Chain : []
# hash_Index : 16 : value 0 : Seprate Chain : []
# hash_Index : 17 : value 0 : Seprate Chain : []
# hash_Index : 18 : value 0 : Seprate Chain : []
# hash_Index : 19 : value 0 : Seprate Chain : []
# hash_Index : 20 : value 0 : Seprate Chain : []
# hash_Index : 21 : value 1106001921 : Seprate Chain : []
# hash_Index : 22 : value 0 : Seprate Chain : []
# hash_Index : 23 : value 0 : Seprate Chain : []
# hash_Index : 24 : value 1314301245 : Seprate Chain : []
# hash_Index : 25 : value 0 : Seprate Chain : []
# hash_Index : 26 : value 0 : Seprate Chain : []
# hash_Index : 27 : value 0202574115 : Seprate Chain : []
# hash_Index : 28 : value 2337405211 : Seprate Chain : ['0053400295']
# hash_Index : 29 : value 0 : Seprate Chain : []
# hash_Index : 30 : value 3149024322 : Seprate Chain : []
# hash_Index : 31 : value 0 : Seprate Chain : []
# hash_Index : 32 : value 0 : Seprate Chain : []
# hash_Index : 33 : value 3332547150 : Seprate Chain : ['3011809623', '1474601244']
# hash_Index : 34 : value 4314343462 : Seprate Chain : ['5311167721']
# hash_Index : 35 : value 9036590021 : Seprate Chain : ['8142073910']
# hash_Index : 36 : value 3974013081 : Seprate Chain : ['0631901376', '4741415235', '7752533310']
# hash_Index : 37 : value 0471620656 : Seprate Chain : ['4216629331', '6150281824', '5243265037', '4743290071', '3123237646', '1147086055', '5570828101']
# hash_Index : 38 : value 2225864144 : Seprate Chain : ['4305139229', '0224272784', '4113978005', '1602390836']
# hash_Index : 39 : value 3528209172 : Seprate Chain : ['4130647059', '7040526249', '5219323806']
# hash_Index : 40 : value 8705661106 : Seprate Chain : ['2766916111', '2923424338', '1564139065', '0921046981']
# hash_Index : 41 : value 4158396203 : Seprate Chain : ['2666640650', '6580281920', '6555132347', '9545662040', '2677415432']
# hash_Index : 42 : value 6146697021 : Seprate Chain : []
# hash_Index : 43 : value 0543362389 : Seprate Chain : ['9921184144', '7469320660', '4735434328', '3233375917', '7109502748']
# hash_Index : 44 : value 0069590933 : Seprate Chain : ['7965064223']
# hash_Index : 45 : value 1958339322 : Seprate Chain : ['3584577510', '0702681696', '8197321437', '0129653199', '5620584573']
# hash_Index : 46 : value 5472785422 : Seprate Chain : ['6156913168', '6612188185']
# hash_Index : 47 : value 9173145764 : Seprate Chain : ['6122759159', '5950563329', '5644927136']
# hash_Index : 48 : value 9692016177 : Seprate Chain : ['0881395932']
# hash_Index : 49 : value 6647701189 : Seprate Chain : ['1396932088', '2341989922', '3991987111', '7783811455']
# hash_Index : 50 : value 6189603953 : Seprate Chain : ['9284268074', '7342365668']
# hash_Index : 51 : value 5248348782 : Seprate Chain : ['3796641915', '8898201654', '7763359317']
# hash_Index : 52 : value 6305372989 : Seprate Chain : ['4080789376']
# hash_Index : 53 : value 0896708069 : Seprate Chain : ['7806709646', '1965683078', '0466689635']
# hash_Index : 54 : value 8801869572 : Seprate Chain : ['7868627091', '9506874717']
# hash_Index : 55 : value 8490537577 : Seprate Chain : ['8506690795']
# hash_Index : 56 : value 2664939287 : Seprate Chain : []
# hash_Index : 57 : value 0 : Seprate Chain : []
# hash_Index : 58 : value 8247438895 : Seprate Chain : ['9329449378']
# hash_Index : 59 : value 0 : Seprate Chain : []
# hash_Index : 60 : value 0557983959 : Seprate Chain : ['3469906878']
# hash_Index : 61 : value 7395953488 : Seprate Chain : []
# hash_Index : 62 : value 0 : Seprate Chain : []
# hash_Index : 63 : value 0 : Seprate Chain : []
# hash_Index : 64 : value 0 : Seprate Chain : []
# hash_Index : 65 : value 0 : Seprate Chain : []
# hash_Index : 66 : value 1397895978 : Seprate Chain : []
# hash_Index : 67 : value 0 : Seprate Chain : []
# hash_Index : 68 : value 0 : Seprate Chain : []
# hash_Index : 69 : value 0 : Seprate Chain : []
# hash_Index : 70 : value 0 : Seprate Chain : []
# hash_Index : 71 : value 0 : Seprate Chain : []
# hash_Index : 72 : value 0 : Seprate Chain : []
# hash_Index : 73 : value 7979448799 : Seprate Chain : []
# hash_Index : 74 : value 0 : Seprate Chain : []
# hash_Index : 75 : value 0 : Seprate Chain : []
# hash_Index : 76 : value 0 : Seprate Chain : []
# hash_Index : 77 : value 0 : Seprate Chain : []
# hash_Index : 78 : value 0 : Seprate Chain : []
# hash_Index : 79 : value 0 : Seprate Chain : []
# hash_Index : 80 : value 0 : Seprate Chain : []
# hash_Index : 81 : value 0 : Seprate Chain : []
# hash_Index : 82 : value 0 : Seprate Chain : []
# hash_Index : 83 : value 0 : Seprate Chain : []
# hash_Index : 84 : value 0 : Seprate Chain : []
# hash_Index : 85 : value 0 : Seprate Chain : []
# hash_Index : 86 : value 0 : Seprate Chain : []
# hash_Index : 87 : value 0 : Seprate Chain : []
# hash_Index : 88 : value 0 : Seprate Chain : []
# hash_Index : 89 : value 0 : Seprate Chain : []
# hash_Index : 90 : value 0 : Seprate Chain : []
# hash_Index : 91 : value 0 : Seprate Chain : []
# hash_Index : 92 : value 0 : Seprate Chain : []
# hash_Index : 93 : value 0 : Seprate Chain : []
# hash_Index : 94 : value 0 : Seprate Chain : []
# hash_Index : 95 : value 0 : Seprate Chain : []
# hash_Index : 96 : value 0 : Seprate Chain : []
# hash_Index : 97 : value 0 : Seprate Chain : []
# hash_Index : 98 : value 0 : Seprate Chain : []
# hash_Index : 99 : value 0 : Seprate Chain : []
# hash_Index : 100 : value 0 : Seprate Chain : []
# hash_Index : 101 : value 0 : Seprate Chain : []
# hash_Index : 102 : value 0 : Seprate Chain : []
# hash_Index : 103 : value 0 : Seprate Chain : []
# hash_Index : 104 : value 0 : Seprate Chain : []
# hash_Index : 105 : value 0 : Seprate Chain : []
# hash_Index : 106 : value 0 : Seprate Chain : []
# hash_Index : 107 : value 0 : Seprate Chain : []
# hash_Index : 108 : value 0 : Seprate Chain : []
# hash_Index : 109 : value 0 : Seprate Chain : []
# hash_Index : 110 : value 0 : Seprate Chain : []
# hash_Index : 111 : value 0 : Seprate Chain : []
# hash_Index : 112 : value 0 : Seprate Chain : []
# hash_Index : 113 : value 0 : Seprate Chain : []
# hash_Index : 114 : value 0 : Seprate Chain : []
# hash_Index : 115 : value 0 : Seprate Chain : []
# hash_Index : 116 : value 0 : Seprate Chain : []
# hash_Index : 117 : value 0 : Seprate Chain : []
# hash_Index : 118 : value 0 : Seprate Chain : []
# hash_Index : 119 : value 0 : Seprate Chain : []
# hash_Index : 120 : value 0 : Seprate Chain : []
# hash_Index : 121 : value 0 : Seprate Chain : []
# hash_Index : 122 : value 0 : Seprate Chain : []
# hash_Index : 123 : value 0 : Seprate Chain : []
# hash_Index : 124 : value 0 : Seprate Chain : []
# hash_Index : 125 : value 0 : Seprate Chain : []
# hash_Index : 126 : value 0 : Seprate Chain : []
# hash_Index : 127 : value 0 : Seprate Chain : []
# hash_Index : 128 : value 0 : Seprate Chain : []
# hash_Index : 129 : value 0 : Seprate Chain : []
# hash_Index : 130 : value 0 : Seprate Chain : []
# hash_Index : 131 : value 0 : Seprate Chain : []
# hash_Index : 132 : value 0 : Seprate Chain : []
# hash_Index : 133 : value 0 : Seprate Chain : []
# hash_Index : 134 : value 0 : Seprate Chain : []
# hash_Index : 135 : value 0 : Seprate Chain : []
# hash_Index : 136 : value 0 : Seprate Chain : []
# hash_Index : 137 : value 0 : Seprate Chain : []
# hash_Index : 138 : value 0 : Seprate Chain : []
# hash_Index : 139 : value 0 : Seprate Chain : []
# hash_Index : 140 : value 0 : Seprate Chain : []
# hash_Index : 141 : value 0 : Seprate Chain : []
# hash_Index : 142 : value 0 : Seprate Chain : []
# hash_Index : 143 : value 0 : Seprate Chain : []
# hash_Index : 144 : value 0 : Seprate Chain : []
# hash_Index : 145 : value 0 : Seprate Chain : []
# hash_Index : 146 : value 0 : Seprate Chain : []
# hash_Index : 147 : value 0 : Seprate Chain : []
# hash_Index : 148 : value 0 : Seprate Chain : []
# hash_Index : 149 : value 0 : Seprate Chain : []
# hash_Index : 150 : value 0 : Seprate Chain : []
# hash_Index : 151 : value 0 : Seprate Chain : []
# hash_Index : 152 : value 0 : Seprate Chain : []
# hash_Index : 153 : value 0 : Seprate Chain : []
# hash_Index : 154 : value 0 : Seprate Chain : []
# hash_Index : 155 : value 0 : Seprate Chain : []
# hash_Index : 156 : value 0 : Seprate Chain : []
# hash_Index : 157 : value 0 : Seprate Chain : []
# hash_Index : 158 : value 0 : Seprate Chain : []
# hash_Index : 159 : value 0 : Seprate Chain : []
# hash_Index : 160 : value 0 : Seprate Chain : []
# hash_Index : 161 : value 0 : Seprate Chain : []
# hash_Index : 162 : value 0 : Seprate Chain : []
# hash_Index : 163 : value 0 : Seprate Chain : []
# hash_Index : 164 : value 0 : Seprate Chain : []
# hash_Index : 165 : value 0 : Seprate Chain : []
# hash_Index : 166 : value 0 : Seprate Chain : []
# hash_Index : 167 : value 0 : Seprate Chain : []
# hash_Index : 168 : value 0 : Seprate Chain : []
# hash_Index : 169 : value 0 : Seprate Chain : []
# hash_Index : 170 : value 0 : Seprate Chain : []
# hash_Index : 171 : value 0 : Seprate Chain : []
# hash_Index : 172 : value 0 : Seprate Chain : []
# hash_Index : 173 : value 0 : Seprate Chain : []
# hash_Index : 174 : value 0 : Seprate Chain : []
# hash_Index : 175 : value 0 : Seprate Chain : []
# hash_Index : 176 : value 0 : Seprate Chain : []
# hash_Index : 177 : value 0 : Seprate Chain : []
# hash_Index : 178 : value 0 : Seprate Chain : []
# hash_Index : 179 : value 0 : Seprate Chain : []
# hash_Index : 180 : value 0 : Seprate Chain : []
# hash_Index : 181 : value 0 : Seprate Chain : []
# hash_Index : 182 : value 0 : Seprate Chain : []
# hash_Index : 183 : value 0 : Seprate Chain : []
# hash_Index : 184 : value 0 : Seprate Chain : []
# hash_Index : 185 : value 0 : Seprate Chain : []
# hash_Index : 186 : value 0 : Seprate Chain : []
# hash_Index : 187 : value 0 : Seprate Chain : []
# hash_Index : 188 : value 0 : Seprate Chain : []
# hash_Index : 189 : value 0 : Seprate Chain : []
# hash_Index : 190 : value 0 : Seprate Chain : []
# hash_Index : 191 : value 0 : Seprate Chain : []
# hash_Index : 192 : value 0 : Seprate Chain : []
# hash_Index : 193 : value 0 : Seprate Chain : []
# hash_Index : 194 : value 0 : Seprate Chain : []
# hash_Index : 195 : value 0 : Seprate Chain : []
# hash_Index : 196 : value 0 : Seprate Chain : []
# hash_Index : 197 : value 0 : Seprate Chain : []
# hash_Index : 198 : value 0 : Seprate Chain : []
# hash_Index : 199 : value 0 : Seprate Chain : []
# hash_Index : 200 : value 0 : Seprate Chain : []
# hash_Index : 201 : value 0 : Seprate Chain : []
# hash_Index : 202 : value 0 : Seprate Chain : []
# hash_Index : 203 : value 0 : Seprate Chain : []
# hash_Index : 204 : value 0 : Seprate Chain : []
# hash_Index : 205 : value 0 : Seprate Chain : []
# hash_Index : 206 : value 0 : Seprate Chain : []
# hash_Index : 207 : value 0 : Seprate Chain : []
# hash_Index : 208 : value 0 : Seprate Chain : []
# hash_Index : 209 : value 0 : Seprate Chain : []
# hash_Index : 210 : value 0 : Seprate Chain : []
# hash_Index : 211 : value 0 : Seprate Chain : []
# hash_Index : 212 : value 0 : Seprate Chain : []
# hash_Index : 213 : value 0 : Seprate Chain : []
# hash_Index : 214 : value 0 : Seprate Chain : []
# hash_Index : 215 : value 0 : Seprate Chain : []
# hash_Index : 216 : value 0 : Seprate Chain : []
# hash_Index : 217 : value 0 : Seprate Chain : []
# hash_Index : 218 : value 0 : Seprate Chain : []
# hash_Index : 219 : value 0 : Seprate Chain : []
# hash_Index : 220 : value 0 : Seprate Chain : []
# hash_Index : 221 : value 0 : Seprate Chain : []
# hash_Index : 222 : value 0 : Seprate Chain : []
# hash_Index : 223 : value 0 : Seprate Chain : []
# hash_Index : 224 : value 0 : Seprate Chain : []
# hash_Index : 225 : value 0 : Seprate Chain : []
# hash_Index : 226 : value 0 : Seprate Chain : []
# hash_Index : 227 : value 0 : Seprate Chain : []
# hash_Index : 228 : value 0 : Seprate Chain : []
# hash_Index : 229 : value 0 : Seprate Chain : []
# hash_Index : 230 : value 0 : Seprate Chain : []
# hash_Index : 231 : value 0 : Seprate Chain : []
# hash_Index : 232 : value 0 : Seprate Chain : []
# hash_Index : 233 : value 0 : Seprate Chain : []
# hash_Index : 234 : value 0 : Seprate Chain : []
# hash_Index : 235 : value 0 : Seprate Chain : []
# hash_Index : 236 : value 0 : Seprate Chain : []
# hash_Index : 237 : value 0 : Seprate Chain : []
# hash_Index : 238 : value 0 : Seprate Chain : []
# hash_Index : 239 : value 0 : Seprate Chain : []
# hash_Index : 240 : value 0 : Seprate Chain : []
# hash_Index : 241 : value 0 : Seprate Chain : []
# hash_Index : 242 : value 0 : Seprate Chain : []
# hash_Index : 243 : value 0 : Seprate Chain : []
# hash_Index : 244 : value 0 : Seprate Chain : []
# hash_Index : 245 : value 0 : Seprate Chain : []
# hash_Index : 246 : value 0 : Seprate Chain : []
# hash_Index : 247 : value 0 : Seprate Chain : []
# hash_Index : 248 : value 0 : Seprate Chain : []
# hash_Index : 249 : value 0 : Seprate Chain : []
# hash_Index : 250 : value 0 : Seprate Chain : []
# hash_Index : 251 : value 0 : Seprate Chain : []
# hash_Index : 252 : value 0 : Seprate Chain : []
# hash_Index : 253 : value 0 : Seprate Chain : []
# hash_Index : 254 : value 0 : Seprate Chain : []
# hash_Index : 255 : value 0 : Seprate Chain : []

# %%
def hash_finder(phone_num):
    global hash_table,sp
    flag = 0
    key = reduce(lambda x,y:int(x)+int(y),phone_num) #hash function which creates index
    if hash_table[key] == phone_num:
        print("Found in the main")
        flag = 1
    else:
        for s in sp[key]:
            if s == phone_num:
                print("Found in the Seprate Chain Hash Index: {}".format(key))
                flag = 1
                break
    if flag ==0:
        print("Hash not Present")

# %%
hash_finder("4743290071")
# Out:
# Found in the Seprate Chain Hash Index: 37

# %%
def hash_remover(phone_num):
    global hash_table,sp
    flag = 0
    key = reduce(lambda x,y:int(x)+int(y),phone_num)
    if hash_table[key] == phone_num:
        print("Found in the main")
        hash_table[key] = 0
    else:
        for s in sp[key]:
            if s == phone_num:
                print("Found and Removed from the Seprate Chain Hash Index: {}".format(key))
                sp[key].remove(s)
                flag = 1
                break
    if flag ==0:
        print("Hash not Present")

# %%
hash_remover("4743290071")
# Out:
# Found and Removed from the Seprate Chain Hash Index: 37

# %%
hash_remover("4743290071")
# Out:
# Hash not Present
